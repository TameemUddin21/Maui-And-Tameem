# %%
import numpy as np

print("this worked" )
import datetime


def greet(name):
    current_time = datetime.datetime.now().strftime("%H:%M:%S")
    print(f"[{current_time}] Hello, {name}!")
# Out:
# this worked

# %% [markdown]
# Just a test run
